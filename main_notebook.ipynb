# %%
from functions.functions import *
import os
import sys
import time

# %%
for image_path in os.listdir("data/"):
    if image_path.endswith(".png"):
        t0 = time.time()
        color_matrix = get_color_matrix(f"data/{image_path}")
        indexed_matrix, color_dict = convert_color_matrix(color_matrix)
        matrix = solver_final(indexed_matrix, color_dict)
        print(f"Image: {image_path} - Time taken: {time.time() - t0:.2f} seconds")
        plot_indexed_matrix(matrix, color_dict)
# Out:
# Solved!
# Image: 151.png - Time taken: 0.02 seconds
# Solved!
# Image: 170.png - Time taken: 0.04 seconds
# Solved!
# Image: 297.png - Time taken: 0.03 seconds
# Solved!
# Image: 312.png - Time taken: 0.04 seconds
# Solved!
# Image: 324.png - Time taken: 0.02 seconds
# Solved!
# Image: 326.png - Time taken: 0.04 seconds
# Solved!
# Image: 77.png - Time taken: 0.01 seconds
